# %%
# lets import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#lets import the data

dt = pd.read_csv('C:/Users/GS/OneDrive/Desktop/Python/Project ( Linear and Logistic Regression)/Linear+Regression+and+Logistic+Regression+in+Python/Linear Regression and Logistic Regression in Python/Data Files/Linear Regression/House_Price.csv',header = 0)

# %%
dt
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
# let do some univariate analysis.

dt.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
dt.shape
# Out:
# (506, 19)

# %%
dt.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
#### in n_hos_rooms and waterbody , there are 8 and 155 values mises respectively.

# %%
sns.jointplot(x = 'n_hot_rooms', y = 'price', data = dt)

# %%
### so there are some outliers at price 15 where n_hot_rooms is 82 and at 101, the price is 35.

# %%
sns.jointplot(x='crime_rate', y = 'price', data = dt)

# %%
### the crime rate is right or postive skewed because its mean is larger than median 
### and the scatter plot is showing the negative correlation between crime_rate and price

# %%
sns.jointplot(x = 'rainfall', y = 'price', data=dt)

# %%
### there is an outlier at price value 28, and there is no relation among price and rainfall.

# %%
# Lets explore the categorical variables.
dt.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x= 'airport', data = dt)
# Out:
# <Axes: xlabel='airport', ylabel='count'>

# %%
#### there are two value yes and no in it.

# %%
dt1 = dt.copy()

# %%
dt1['waterbody'].fillna('NaN',inplace = True)

# %%
sns.countplot(x = 'waterbody', data = dt1)
# Out:
# <Axes: xlabel='waterbody', ylabel='count'>

# %%
#### first we made a copy of original file and fillna missing value with NaN and 
#### plot the countpot, becuase we cannot utilize fillna function inside the counplot.

# %%
sns.countplot(x = 'bus_ter', data = dt1)
# Out:
# <Axes: xlabel='bus_ter', ylabel='count'>

# %%
#### there is only one value Yes which cannot be helpful to prdeict the dependent variable(price), so we should drop it.

# %%
# Treatment of outliers

np.percentile(dt1.n_hot_rooms,[99])[0]
# Out:
# 15.39952

# %%
upperlimit = np.percentile(dt1.n_hot_rooms,[99])[0]

# %%
dt1[dt1['n_hot_rooms']>upperlimit]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
### only two values are greater than 3 times of the upper limit, lets treat them

# %%
dt1['n_hot_rooms'][dt1['n_hot_rooms']> 3*upperlimit] = 3*upperlimit
# Out:
# C:\Users\GS\AppData\Local\Temp\ipykernel_7520\993589603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt1['n_hot_rooms'][dt1['n_hot_rooms']> 3*upperlimit] = 3*upperlimit

# %%
dt1[dt1['n_hot_rooms']>upperlimit]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# ...

# %%
# lets treat the outlier in rainfall as we previous conclude that values are on the lower side it means we use lower percentile to check and treat.

lowerlimit = np.percentile(dt1.rainfall,[1])[0]
lowerlimit
# Out:
# 20.0

# %%
dt1[dt1['rainfall']<lowerlimit]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213       NaN         3     YES  0.044019

# %%
dt1['rainfall'][dt1['rainfall']< 0.3*lowerlimit] = 0.3*lowerlimit
# Out:
# C:\Users\GS\AppData\Local\Temp\ipykernel_7520\1058404432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt1['rainfall'][dt1['rainfall']< 0.3*lowerlimit] = 0.3*lowerlimit

# %%
dt1[dt1['rainfall']<lowerlimit]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213       NaN         6     YES  0.044019

# %%
type(dt1).describe(dt1)
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
dt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.jointplot( x= 'n_hos_beds', y = 'price', data= dt1)

# %%
dt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
# mean data impute in n_hos_beds. ( from zero, mean(numerical),median(numerical),mode(for categorical), 
# and segment based mean(numerical), median(numerical) and mode(for categorical))

dt1['n_hos_beds']  = dt1['n_hos_beds'].fillna(dt1['n_hos_beds'].mean())

# %%
# lets create a logarthemic graph between price and crime rate.
sns.jointplot(x = 'crime_rate', y = 'price', data = dt1)

# %%
dt1['crime_rate'] = np.log(1+dt1['crime_rate'])

# %%
sns.jointplot(x = 'crime_rate', y = 'price', data = dt1)

# %%
sns.histplot(x='crime_rate',data = dt)
# Out:
# <Axes: xlabel='crime_rate', ylabel='Count'>

# %%
dt1.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# lets the average of distance (employement hub distant). It could be change on the need of end user 
# either average, max, min form these four data column

# %%
dt1['Ave_dist'] = (dt1['dist1']+dt1['dist2']+dt1['dist3']+dt1['dist4'])/4

# %%
dt1.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks  Ave_dist
# 0     River        23     YES  0.049347    4.0875
# ...

# %%
# now delete the dist1 to dist4


del dt1['dist1']
del dt1['dist2']
del dt1['dist3']
del dt1['dist4']

# %%
dt1.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall bus_ter  \
# 0       4.98     YES       5.480     11.19200     River        23     YES
# 1       9.14      NO       7.332     12.17280      Lake        42     YES
# 2       4.03      NO       7.394     46.19856       NaN        38     YES
# 3       2.94     YES       9.268     11.26720      Lake        45     YES
# 4       5.33      NO       8.824     11.28960      Lake        55     YES
#
#       parks  Ave_dist
# 0  0.049347    4.0875
# 1  0.046146    4.9675
# 2  0.045764    4.9675
# ...

# %%
# delete the bus_terminal aswell as we checked earlier that it has only one value that was Yes.

del dt1['bus_ter']

# %%
dt1.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# 1       9.14      NO       7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO       7.394     46.19856       NaN        38  0.045764
# 3       2.94     YES       9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO       8.824     11.28960      Lake        55  0.039474
#
#    Ave_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
# let do some addition of dummy variable on non numeric data or nominal data.
dt1 = pd.get_dummies(dt1)

# %%
dt1
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0     24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1     21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2     34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3     33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4     36.2    0.066770       32.18     0.458     7.147  54.2      21.3
# ..     ...         ...         ...       ...       ...   ...       ...
# 501   22.4    0.060747       41.93     0.573     6.593  69.1      19.0
# 502   20.6    0.044275       41.93     0.573     6.120  76.7      19.0
# 503   23.9    0.058986       41.93     0.573     6.976  91.0      19.0
# 504   22.0    0.103991       41.93     0.573     6.794  89.3      19.0
# 505   19.0    0.046320       41.93     0.573     6.030  80.8      19.0
#
#      poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  Ave_dist  \
# ...

# %%
#### so we don't need to use airport_no here as airport_yes clearly elaborate the message of having the
#### airport in the respective price value.same goes for waterbogy_none.

del dt1['airport_NO']
del dt1['waterbody_NaN']

# %%
dt1.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  Ave_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
# now we will do some correlation analysis between dependent and independent varibles and between independent variables.

corr = dt1.corr()
sns.heatmap(corr,xticklabels=corr.columns.values,
           yticklabels=corr.columns.values)
# Out:
# <Axes: >

# %%
corr
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# Ave_dist                  0.249289   -0.586371   -0.708022 -0.769247
# ...

# %%
### here we can check the relation between room and price are highly positively related as compared to other variables. The other variable 
### called poor_prop also related but negatively with price. Among independent variables like parks and air quality, the relation is high so it can 
### create multicollinearity in the model, so we will delete one of them on the basis of (how it relate with dependent variable or accoeding to our business
### knowledge)
del dt1['parks']

# %%
### Let check the statsitcs of linear model

import statsmodels.api as sn

# %%
#### by default stats model do not contain beta not constant or intercept, so we defined it. 
x = sn.add_constant(dt1['room_num'])

# %%
### lets fit the model in ordinary least square (OLS stands for Ordinary Least Squares, and 
### it is a method used for estimating the parameters in a linear regression model. In the context 
### of linear regression, the goal is to find the best-fitting line through the data by minimizing 
### the sum of the squared differences (residuals) between the observed values and the values predicted by the model.)
### x is  independent variables (features)
### dependent variable (response variable) 
### fit(): This method fits the linear regression model to the data.
lm = sn.OLS(dt1['price'], x).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           1.31e-74
# Time:                        12:33:56   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
### Interprate.
## 1) Model is OLS (Ordinary least square)
## 2) Beta knot (-34.6592) or intercept
## 3) Beta 1 (room_num) (9.0997)(slope)(it means if x=1 so y will increase by beta1 quantity that is 9.0997)
## 4) Standard Error (it measures the error or variability of predicted and actual value in the model, the model is not 
##     completely describe the result accurately, it will differ by 0.418 in beta 1 and 2.642 in intercept, which means model could
##     not completetly capture the variability of dependent variable).
## 5) t is calculated using beta one/ standard error, so high error means low t which is not good so high t would be favorable.
##    t-statistics, P>|t| values: These values assess the statistical significance of each coefficient. A low p-value (typically below 0.05) 
##    suggests that the corresponding variable is statistically significant.
## 6) p is a threshold point which tells if we get p value below than 1% or 5%, that tell the model has fitted well.
## 7) R squared value ( R squared is a measure of how well the independent variables explain the variability of the dependent variable
##    (It ranges from 0 to 1).1 means model understand the variability well whereas 0 means model have not understood well. )
## 8) Adjusted R squared means it same as R squared with a small difference like the (The Adjusted R-squared is a modified version of 
##    the R-squared (coefficient of determination) in the context of linear regression models. While R-squared tells you the proportion of 
##    the variance in the dependent variable explained by the independent variables, Adjusted R-squared takes into account the number of 
##    predictors (independent variables) in the model, providing a more nuanced measure of model performance.) 
##   The concept of Adjusted R squared
##   Adjusted R-squared adjusts the R-squared value to account for the number of predictors in the model. It penalizes 
##   the use of additional predictors that do not contribute significantly to explaining the variance in the dependent variable.
## 9) The F-statistic tests the overall significance of the regression model. A low p-value (close to zero) suggests that at 
##   least one independent variable has a significant effect on the dependent variable.

# %%
### let do this model with sklearn

from sklearn.linear_model import LinearRegression

# %%
y = dt1['price']
x = dt1[['room_num']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# -34.65924312309723 [9.09966966]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, default=None
# ...

# %%
y1 =lm2.predict(x)

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(data=None, *, x=None, y=None, hue=None, kind='scatter', height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, color=None, palette=None, hue_order=None, hue_norm=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#         Input data structure. Either a long-form collection of vectors that can be
#         assigned to named variables or a wide-form dataset that will be internally
#         reshaped.
# ...

# %%
sns.jointplot(x= dt1['room_num'],y=dt1['price'],data=dt1, kind = 'reg')

# %%
sns.jointplot(x= dt1['room_num'],y=y1,data=dt1, kind = 'reg')

# %%
dt1['airport_YES'] = dt1['airport_YES'].astype('int')
dt1['waterbody_Lake'] = dt1['waterbody_Lake'].astype('int')
dt1['waterbody_Lake and River'] = dt1['waterbody_Lake and River'].astype('int')
dt1['waterbody_River'] = dt1['waterbody_River'].astype('int')

# %%
### let do this with multiple regression analysis.

x_multi = dt1.drop('price',axis=1)

# %%
x_multi
# Out:
#      crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0      0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1      0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2      0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3      0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4      0.066770       32.18     0.458     7.147  54.2      21.3       5.33
# ..          ...         ...       ...       ...   ...       ...        ...
# 501    0.060747       41.93     0.573     6.593  69.1      19.0       9.67
# 502    0.044275       41.93     0.573     6.120  76.7      19.0       9.08
# 503    0.058986       41.93     0.573     6.976  91.0      19.0       5.64
# 504    0.103991       41.93     0.573     6.794  89.3      19.0       6.48
# 505    0.046320       41.93     0.573     6.030  80.8      19.0       7.88
#
# ...

# %%
y_multi = dt1['price']
y_multi
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    19.0
# Name: price, Length: 506, dtype: float64

# %%
import statsmodels.api as sn

# %%
## As we now by default statsmodels can not define the intercept value so we use add constant here.

x_multi_cons = sn.add_constant(x_multi)
x_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  Ave_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# 0               0                         0                1
# ...

# %%
lm_multi =  sn.OLS(y_multi,x_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     84.34
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):          4.19e-125
# Time:                        14:37:13   Log-Likelihood:                -1516.6
# No. Observations:                 506   AIC:                             3065.
# Df Residuals:                     490   BIC:                             3133.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
## R squared value is pretty good.
## F statistic also less than 5% it means we can say our independent variable have some impact on our dependent variable.
## degree of freedom is calculated using (no. of observation-total independent variable-1)

# %%
## Condition Number (Cond. No.):
## Values below 10: No or very weak multicollinearity.
## Values between 10 and 30: Moderate multicollinearity (may be a concern in some cases).
## Values above 30: Potential indication of multicollinearity.
## Values above 100: Strong indication of severe multicollinearity.

# %%
## let do this sklearn library

lm_multi1= LinearRegression()

# %%
lm_multi1.fit(x_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm_multi1.intercept_,lm_multi1.coef_)
# Out:
# -6.498625198419504 [ 9.70998193e-03 -4.08746495e-02 -1.58973999e+01  4.01901676e+00
#  -5.71475069e-03  1.00700068e+00 -5.77271243e-01  3.29221139e-01
#   9.18675603e-02  1.61185504e-02 -1.21863952e+00  1.13151586e+00
#   2.64086064e-01 -6.87555889e-01 -2.91318712e-01]

# %%
### let do test and train the model using Sklearn

from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_multi,y_multi,test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (404, 15) (102, 15) (404,) (102,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(x_test)

# %%
y_train_a = lm_a.predict(x_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.5496468288205665

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.7564635405911231

# %%
### we should look to the test result rather than train result becuase sometime good train result is not depicting the realness of prediction.
